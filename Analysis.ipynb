# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# # Data Colection

# %%
# Loading data
reliance_data = pd.read_csv("reliance_data.csv")

# %%
reliance_data
# Out:
#             Date        Open          High          Low        Close
# 0     01-01-2014   444.511475   444.907715   439.632721   440.227081  \
# 1     02-01-2014   439.682251   443.793274   430.964874   433.391876
# 2     03-01-2014   431.707855   432.574615   423.485779   428.067352
# 3     06-01-2014   427.002441   427.572052   421.009247   423.460999
# 4     07-01-2014   423.287659   425.937531   416.080963   417.096344
# ...          ...          ...          ...          ...          ...
# 2217  26-12-2022  2514.750000  2542.000000  2492.399902  2524.050049
# 2218  27-12-2022  2530.000000  2548.800049  2515.250000  2544.699951
# 2219  28-12-2022  2538.000000  2549.800049  2521.500000  2544.449951
# 2220  29-12-2022  2527.000000  2548.899902  2525.500000  2543.300049
# 2221  30-12-2022  2545.100098  2577.000000  2541.100098  2547.199951
#
#         Adj Close     Volume
# 0      414.639191  2699496.0
# 1      408.201294  2779905.0
# 2      403.186218  5922841.0
# 3      398.847626  6145266.0
# 4      392.852966  7989240.0
# ...           ...        ...
# 2217  2524.050049  2764496.0
# 2218  2544.699951  2659749.0
# 2219  2544.449951  3442509.0
# 2220  2543.300049  3198493.0
# 2221  2547.199951  3364092.0
#
# [2222 rows x 7 columns]

# %%
# Loading data
nifty_data = pd.read_csv("nifty_50_data.csv")

# %%
nifty_data
# Out:
#             Date          Open          High           Low         Close
# 0     01-01-2014           NaN           NaN           NaN           NaN  \
# 1     02-01-2014   6301.250000   6358.299805   6211.299805   6221.149902
# 2     03-01-2014   6194.549805   6221.700195   6171.250000   6211.149902
# 3     06-01-2014   6220.850098   6224.700195   6170.250000   6191.450195
# 4     07-01-2014   6203.899902   6221.500000   6144.750000   6162.250000
# ...          ...           ...           ...           ...           ...
# 2217  26-12-2022  17830.400390  18084.099610  17774.250000  18014.599610
# 2218  27-12-2022  18089.800780  18149.250000  17967.449220  18132.300780
# 2219  28-12-2022  18084.750000  18173.099610  18068.349610  18122.500000
# 2220  29-12-2022  18045.699220  18229.699220  17992.800780  18191.000000
# 2221  30-12-2022  18259.099610  18265.250000  18080.300780  18105.300780
#
#          Adj Close    Volume
# 0              NaN       NaN
# 1      6221.149902  158100.0
# 2      6211.149902  139000.0
# 3      6191.450195  118300.0
# 4      6162.250000  138600.0
# ...            ...       ...
# 2217  18014.599610  176700.0
# 2218  18132.300780  214300.0
# 2219  18122.500000  193900.0
# 2220  18191.000000  281100.0
# 2221  18105.300780  192000.0
#
# [2222 rows x 7 columns]

# %% [markdown]
# # Data Preparation

# %%
# Dealing with NAN values
reliance_data[reliance_data.isna().any(axis=1)]
# Out:
#            Date  Open   High  Low  Close  Adj Close  Volume
# 56   22-03-2014    NaN   NaN  NaN    NaN        NaN     NaN
# 285  28-02-2015    NaN   NaN  NaN    NaN        NaN     NaN

# %%
reliance_data.dropna(inplace=True)

# %%
reliance_data.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
reliance_data.duplicated().sum()
# Out:
# 0

# %%
#Dealing with NAN values
nifty_data.isna().sum()
# Out:
# Date          0
# Open         14
# High         14
# Low          14
# Close        14
# Adj Close    14
# Volume       14
# dtype: int64

# %%
nifty_data[nifty_data.isna().any(axis=1)]
# Out:
#             Date  Open  High  Low  Close  Adj Close  Volume
# 0     01-01-2014   NaN   NaN  NaN    NaN        NaN     NaN
# 33    17-02-2014   NaN   NaN  NaN    NaN        NaN     NaN
# 56    22-03-2014   NaN   NaN  NaN    NaN        NaN     NaN
# 77    24-04-2014   NaN   NaN  NaN    NaN        NaN     NaN
# 194   15-10-2014   NaN   NaN  NaN    NaN        NaN     NaN
# 245   01-01-2015   NaN   NaN  NaN    NaN        NaN     NaN
# 285   28-02-2015   NaN   NaN  NaN    NaN        NaN     NaN
# 314   15-04-2015   NaN   NaN  NaN    NaN        NaN     NaN
# 492   01-01-2016   NaN   NaN  NaN    NaN        NaN     NaN
# 644   12-08-2016   NaN   NaN  NaN    NaN        NaN     NaN
# 986   01-01-2018   NaN   NaN  NaN    NaN        NaN     NaN
# 1232  01-01-2019   NaN   NaN  NaN    NaN        NaN     NaN
# 1430  27-10-2019   NaN   NaN  NaN    NaN        NaN     NaN
# 1694  14-11-2020   NaN   NaN  NaN    NaN        NaN     NaN

# %%
nifty_data.dropna(inplace=True)

# %%
nifty_data.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
nifty_data.duplicated().sum()
# Out:
# 0

# %%
reliance_data.columns
# Out:
# Index(['Date', 'Open ', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
reliance_data.drop(columns = ['Open ', 'High', 'Low', 'Adj Close'], inplace=True)

# %%
nifty_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# Renaming columns
nifty_data.drop(columns = ['Open', 'High', 'Low', 'Adj Close'], inplace=True)

# %%
reliance_data.head()
# Out:
#          Date       Close     Volume
# 0  01-01-2014  440.227081  2699496.0
# 1  02-01-2014  433.391876  2779905.0
# 2  03-01-2014  428.067352  5922841.0
# 3  06-01-2014  423.460999  6145266.0
# 4  07-01-2014  417.096344  7989240.0

# %%
nifty_data.head()
# Out:
#          Date        Close    Volume
# 1  02-01-2014  6221.149902  158100.0
# 2  03-01-2014  6211.149902  139000.0
# 3  06-01-2014  6191.450195  118300.0
# 4  07-01-2014  6162.250000  138600.0
# 5  08-01-2014  6174.600098  146900.0

# %%
reliance_data.shape
# Out:
# (2220, 3)

# %%
nifty_data.shape
# Out:
# (2208, 3)

# %%
#Joining two dataframe to create one final dataframe
df = reliance_data.merge(nifty_data, on='Date', how='inner')

# %%
df.shape
# Out:
# (2208, 5)

# %%
df.head()
# Out:
#          Date     Close_x   Volume_x      Close_y  Volume_y
# 0  02-01-2014  433.391876  2779905.0  6221.149902  158100.0
# 1  03-01-2014  428.067352  5922841.0  6211.149902  139000.0
# 2  06-01-2014  423.460999  6145266.0  6191.450195  118300.0
# 3  07-01-2014  417.096344  7989240.0  6162.250000  138600.0
# 4  08-01-2014  420.538727  5873245.0  6174.600098  146900.0

# %%
df.columns
# Out:
# Index(['Date', 'Close_x', 'Volume_x', 'Close_y', 'Volume_y'], dtype='object')

# %%
df.columns = ['date', 'stock_price', 'stock_vol', 'index_point', 'index_volume']

# %%
df.head()
# Out:
#          date  stock_price  stock_vol  index_point  index_volume
# 0  02-01-2014   433.391876  2779905.0  6221.149902      158100.0
# 1  03-01-2014   428.067352  5922841.0  6211.149902      139000.0
# 2  06-01-2014   423.460999  6145266.0  6191.450195      118300.0
# 3  07-01-2014   417.096344  7989240.0  6162.250000      138600.0
# 4  08-01-2014   420.538727  5873245.0  6174.600098      146900.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2208 non-null   object
#  1   stock_price   2208 non-null   float64
#  2   stock_vol     2208 non-null   float64
#  3   index_point   2208 non-null   float64
#  4   index_volume  2208 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 86.4+ KB

# %%
# Converting float column values to integer
df.stock_price = df.stock_price.astype(int)
df.stock_vol = df.stock_vol.astype(int)
df.index_point = df.index_point.astype(int)
df.index_volume = df.index_volume.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2208 non-null   object
#  1   stock_price   2208 non-null   int32
#  2   stock_vol     2208 non-null   int32
#  3   index_point   2208 non-null   int32
#  4   index_volume  2208 non-null   int32
# dtypes: int32(4), object(1)
# memory usage: 51.9+ KB

# %%
df.head()
# Out:
#          date  stock_price  stock_vol  index_point  index_volume
# 0  02-01-2014          433    2779905         6221        158100
# 1  03-01-2014          428    5922841         6211        139000
# 2  06-01-2014          423    6145266         6191        118300
# 3  07-01-2014          417    7989240         6162        138600
# 4  08-01-2014          420    5873245         6174        146900

# %%
df.tail()
# Out:
#             date  stock_price  stock_vol  index_point  index_volume
# 2203  26-12-2022         2524    2764496        18014        176700
# 2204  27-12-2022         2544    2659749        18132        214300
# 2205  28-12-2022         2544    3442509        18122        193900
# 2206  29-12-2022         2543    3198493        18191        281100
# 2207  30-12-2022         2547    3364092        18105        192000

# %%
# Converting date column from string data type to datetime object
df.date = pd.to_datetime(df.date, format='%d-%m-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2208 non-null   datetime64[ns]
#  1   stock_price   2208 non-null   int32
#  2   stock_vol     2208 non-null   int32
#  3   index_point   2208 non-null   int32
#  4   index_volume  2208 non-null   int32
# dtypes: datetime64[ns](1), int32(4)
# memory usage: 51.9 KB

# %%
df.index_volume.sort_values()
# Out:
# 1103          0
# 1776          0
# 798           0
# 1757          0
# 1640          0
#          ...
# 1512    1388000
# 1420    1414800
# 1515    1516600
# 1509    1565500
# 1508    1811000
# Name: index_volume, Length: 2208, dtype: int32

# %%
# Removing absurd values
temp_df = df[(df.index_volume==0) | (df.index_volume==100) | (df.index_volume==400) | (df.index_volume==500)]
rows_to_drop = temp_df.index
temp_df.head()
# Out:
#            date  stock_price  stock_vol  index_point  index_volume
# 798  2017-04-17          689    5463005         9139             0
# 1054 2018-04-27          986   11776851        10692             0
# 1069 2018-05-21          922    6687690        10516             0
# 1103 2018-07-06          968    9248105        10772             0
# 1108 2018-07-13         1089   18137593        11018             0

# %%
df.drop(index=rows_to_drop, inplace=True)

# %%
df.index_volume.sort_values()
# Out:
# 926       30200
# 1185      31200
# 856       37500
# 2160      45000
# 1920      48500
#          ...
# 1512    1388000
# 1420    1414800
# 1515    1516600
# 1509    1565500
# 1508    1811000
# Name: index_volume, Length: 2183, dtype: int32

# %% [markdown]
# # Data Exploration

# %%
df.describe()
# Out:
#                                 date  stock_price     stock_vol   index_point
# count                           2183  2183.000000  2.183000e+03   2183.000000  \
# mean   2018-07-05 14:49:51.479615232  1221.597343  8.852340e+06  11115.771415
# min              2014-01-02 00:00:00   396.000000  7.871600e+05   6000.000000
# 25%              2016-04-04 12:00:00   501.000000  5.187918e+06   8380.500000
# 50%              2018-06-25 00:00:00   977.000000  7.008431e+06  10454.000000
# 75%              2020-10-08 12:00:00  1964.000000  9.979999e+06  12181.000000
# max              2022-12-30 00:00:00  2819.000000  6.584835e+07  18812.000000
# std                              NaN   758.785120  6.472793e+06   3373.465001
#
#        index_volume
# count  2.183000e+03
# mean   3.154242e+05
# min    3.020000e+04
# 25%    1.728000e+05
# 50%    2.419000e+05
# 75%    3.913500e+05
# max    1.811000e+06
# std    2.057935e+05

# %%
df.stock_price.median(), df.index_point.median()
# Out:
# (977.0, 10454.0)

# %%
print("Mean of reliance stock price: ₹1,221")
print("Median of reliance stock price: ₹977")
print("Standary deviation of reliance stock price: ₹759")
print("")
print("Mean reliance stock price: 11,115")
print("Standary deviation of reliance stock price: 10454")
print("Standary deviation of nifty 50 index point: 3373")
# Out:
# Mean of reliance stock price: ₹1,221
# Median of reliance stock price: ₹977
# Standary deviation of reliance stock price: ₹759
#
# Mean reliance stock price: 11,115
# Standary deviation of reliance stock price: 10454
# Standary deviation of nifty 50 index point: 759

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid", {'grid.color': 'white'})
sns.kdeplot(data=df['stock_price'], color='blue')
plt.title('Stock Price Distribution')
plt.xlabel('Stock Price')
plt.ylabel('Density')
plt.gca().set_facecolor('#e6ffe6')

# %%
# Creating a box plot
fig = px.box(df, y='stock_price')  
fig.update_layout(title='Box Plot of Reliance Stock Prices', yaxis_title='Stock Price')

fig.update_traces(marker_color='blue')
fig.update_layout(plot_bgcolor='#e6ffe6')
fig.update_yaxes(showgrid=True, gridcolor='white', gridwidth=5)

fig.show()
# Out:
# <div>                            <div id="af4c3186-fa19-4c00-b05b-c5e1efc0b468" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af4c3186-fa19-4c00-b05b-c5e1efc0b468")) {                    Plotly.newPlot(                        "af4c3186-fa19-4c00-b05b-c5e1efc0b468",                        [{"alignmentgroup":"True","hovertemplate":"stock_price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"blue"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[433,428,423,417,420,421,425,436,436,438,438,438,430,427,432,428,429,417,418,414,408,411,406,406,404,404,403,407,398,405,399,407,402,402,398,401,402,401,401,396,397,402,399,407,430,438,433,431,435,438,444,447,448,438,448,435,441,446,453,461,466,474,471,467,467,476,479,472,470,466,475,475,479,479,469,468,465,463,459,468,477,475,475,494,509,526,517,521,534,554,534,534,545,558,545,538,539,531,527,536,542,533,539,555,556,553,545,541,535,527,539,528,516,513,514,524,520,501,501,502,499,504,498,511,508,492,495,493,478,476,481,490,486,483,494,510,511,515,506,498,498,498,483,487,487,489,490,485,485,487,490,496,501,499,494,492,494,493,492,492,494,502,507,510,508,508,513,511,503,504,503,496,485,489,497,493,491,478,477,460,462,462,468,459,458,463,472,475,474,476,461,464,463,460,468,466,462,471,485,495,496,490,485,480,484,482,480,480,487,489,484,485,494,488,491,488,489,491,476,476,479,474,474,467,465,461,448,437,435,428,430,435,446,448,442,437,440,444,435,441,438,433,414,423,417,426
# %% [markdown]
# The median of index point is near the first quartile (Q1), it indicates that there are more instances of lower index point compared to higher ones.

# %% [markdown]
# # Correlation Analysis

# %%
# Creating correlation matrix
correlation_matrix = df[['stock_price', 'stock_vol', 'index_point', 'index_volume']]
correlation_matrix = correlation_matrix.corr()
correlation_matrix
# Out:
#               stock_price  stock_vol  index_point  index_volume
# stock_price      1.000000   0.109424     0.946559      0.432842
# stock_vol        0.109424   1.000000    -0.052980      0.503068
# index_point      0.946559  -0.052980     1.000000      0.270758
# index_volume     0.432842   0.503068     0.270758      1.000000

# %%
# Creating a heatmap
fig = go.Figure(data=go.Heatmap(
                   z=correlation_matrix.values,
                   x=correlation_matrix.index,
                   y=correlation_matrix.columns,
                   colorscale='ylgn'))

fig.update_layout(title="Correlation Matrix",
                  xaxis_title="Features",
                  yaxis_title="Features")

fig.show()
# Out:
# <div>                            <div id="3b0c6f49-7721-4928-b51e-2634fccb5687" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b0c6f49-7721-4928-b51e-2634fccb5687")) {                    Plotly.newPlot(                        "3b0c6f49-7721-4928-b51e-2634fccb5687",                        [{"colorscale":[[0.0,"rgb(255,255,229)"],[0.125,"rgb(247,252,185)"],[0.25,"rgb(217,240,163)"],[0.375,"rgb(173,221,142)"],[0.5,"rgb(120,198,121)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,132,67)"],[0.875,"rgb(0,104,55)"],[1.0,"rgb(0,69,41)"]],"x":["stock_price","stock_vol","index_point","index_volume"],"y":["stock_price","stock_vol","index_point","index_volume"],"z":[[1.0,0.10942402065042325,0.9465591294454003,0.43284188887776887],[0.10942402065042325,1.0,-0.052980337327661796,0.5030677823524478],[0.9465591294454003,-0.052980337327661796,1.0,0.2707580996554392],[0.43284188887776887,0.5030677823524478,0.2707580996554392,1.0]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3 ...

# %% [markdown]
# There's strong positive correlation (0.94) between stock price and index point, also weak positive correlation (0.5) exist between stock volumen and index volume.

# %% [markdown]
# # Comparative Analysis

# %%
# Applying moving average to stock_price and index_point column to smoothen the graph
window_size = 30
df['stock_price_smooth'] = df['stock_price'].rolling(window=window_size).mean()
df['index_point_smooth'] = df['index_point'].rolling(window=window_size).mean()

fig = make_subplots(specs=[[{"secondary_y": True}]])

# left y-axis (for stock price)
fig.add_trace(go.Scatter(x=df['date'], y=df['stock_price_smooth'], mode='lines', line_shape='linear',
                         name='Reliance Stock Price', line_color='blue'), secondary_y=False)

# Right y-axis (for index point)
fig.add_trace(go.Scatter(x=df['date'], y=df['index_point_smooth'], mode='lines', line_shape='linear',
                         name='Nifty 50 Index Point', line_color='orange'), secondary_y=True)

fig.update_yaxes(title_text='Reliance Stock Price (₹)', secondary_y=False)
fig.update_yaxes(title_text='Nifty 50 Index Point', secondary_y=True)
fig.update_xaxes(title_text='Date')
fig.update_layout(title_text='Reliance Stock Price vs. Nifty 50 Index Point Movement Over Time')
fig.update_layout(plot_bgcolor='#e6ffe6')
fig.update_xaxes(showgrid=True, gridcolor='white', gridwidth=1)
fig.update_yaxes(showgrid=True, gridcolor='white', gridwidth=1)

fig.show()
# Out:
# <div>                            <div id="997ce305-51b2-4d68-8dbc-6bfe964664e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("997ce305-51b2-4d68-8dbc-6bfe964664e9")) {                    Plotly.newPlot(                        "997ce305-51b2-4d68-8dbc-6bfe964664e9",                        [{"line":{"color":"blue","shape":"linear"},"mode":"lines","name":"Reliance Stock Price","x":["2014-01-02T00:00:00","2014-01-03T00:00:00","2014-01-06T00:00:00","2014-01-07T00:00:00","2014-01-08T00:00:00","2014-01-09T00:00:00","2014-01-10T00:00:00","2014-01-13T00:00:00","2014-01-14T00:00:00","2014-01-15T00:00:00","2014-01-16T00:00:00","2014-01-17T00:00:00","2014-01-20T00:00:00","2014-01-21T00:00:00","2014-01-22T00:00:00","2014-01-23T00:00:00","2014-01-24T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-28T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-25T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-02T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-06-05T00:00:00","2014-06-06T00:00:00","2014-06-09T00:00:00","2014-06-10T00:00:00","2014-06-11T00:00:00","2014-06-12T00:00:00","2014-06-13T00:00:00","2014-06-16T00:00:00","2014-06-17T00:00:00","2014-06-18T00:00:00","2014-06-19T00:00:00","2014-06-20T00:00:00","2014-06-23T00:00:00","2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-06-30T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-04T00:00:00","2014-07-07T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-14T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-21T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-28T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-04T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-11T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-18T00:00:00","2014-08-19 ...

# %% [markdown]
# 1) Most of the time stock price and index point follows same trend with few exceptions.
# 2) Before 2020, we can see one inteval (Mar 2015) where the stock price underperformed the index point.
# 3) After 2020, we can see two intevals (Oct 2020, May 2022) where stock price outperformed the index point.

# %%
# Applying moving average to stock_volume and index_volume column to smoothen the graph
window_size = 50
df['stock_price_smooth'] = df['stock_price'].rolling(window=window_size).mean()
df['stock_volume_smooth'] = df['stock_vol'].rolling(window=window_size).mean()

fig = make_subplots(specs=[[{"secondary_y": True}]])

# left y-axis (for stock volume)
fig.add_trace(go.Scatter(x=df['date'], y=df['stock_price_smooth'], mode='lines', line_shape='linear',
                         name='Reliance Stock Price', line_color = 'blue'), secondary_y=False)

# Right y-axis (for index volume)
fig.add_trace(go.Scatter(x=df['date'], y=df['stock_volume_smooth'], mode='lines', line_shape='linear',
                         name='Reliance Stock Volume', line_color = 'orange'), secondary_y=True)

fig.update_yaxes(title_text='Reliance Stock Price', secondary_y=False)

fig.update_yaxes(title_text='Reliance Stock Volume', secondary_y=True)

fig.update_xaxes(title_text='Date')

fig.update_layout(title_text='Reliance Stock Price vs. Volume Movement Over Time')

fig.update_layout(plot_bgcolor='#e6ffe6')
fig.update_xaxes(showgrid=True, gridcolor='white', gridwidth=1)
fig.update_yaxes(showgrid=True, gridcolor='white', gridwidth=1)

fig.show()
# Out:
# <div>                            <div id="aa41b302-065e-4595-a44d-5b9a73d6fdf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa41b302-065e-4595-a44d-5b9a73d6fdf4")) {                    Plotly.newPlot(                        "aa41b302-065e-4595-a44d-5b9a73d6fdf4",                        [{"line":{"color":"blue","shape":"linear"},"mode":"lines","name":"Reliance Stock Price","x":["2014-01-02T00:00:00","2014-01-03T00:00:00","2014-01-06T00:00:00","2014-01-07T00:00:00","2014-01-08T00:00:00","2014-01-09T00:00:00","2014-01-10T00:00:00","2014-01-13T00:00:00","2014-01-14T00:00:00","2014-01-15T00:00:00","2014-01-16T00:00:00","2014-01-17T00:00:00","2014-01-20T00:00:00","2014-01-21T00:00:00","2014-01-22T00:00:00","2014-01-23T00:00:00","2014-01-24T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-01-29T00:00:00","2014-01-30T00:00:00","2014-01-31T00:00:00","2014-02-03T00:00:00","2014-02-04T00:00:00","2014-02-05T00:00:00","2014-02-06T00:00:00","2014-02-07T00:00:00","2014-02-10T00:00:00","2014-02-11T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-14T00:00:00","2014-02-18T00:00:00","2014-02-19T00:00:00","2014-02-20T00:00:00","2014-02-21T00:00:00","2014-02-24T00:00:00","2014-02-25T00:00:00","2014-02-26T00:00:00","2014-02-28T00:00:00","2014-03-03T00:00:00","2014-03-04T00:00:00","2014-03-05T00:00:00","2014-03-06T00:00:00","2014-03-07T00:00:00","2014-03-10T00:00:00","2014-03-11T00:00:00","2014-03-12T00:00:00","2014-03-13T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-19T00:00:00","2014-03-20T00:00:00","2014-03-21T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T00:00:00","2014-04-15T00:00:00","2014-04-16T00:00:00","2014-04-17T00:00:00","2014-04-21T00:00:00","2014-04-22T00:00:00","2014-04-23T00:00:00","2014-04-25T00:00:00","2014-04-28T00:00:00","2014-04-29T00:00:00","2014-04-30T00:00:00","2014-05-02T00:00:00","2014-05-05T00:00:00","2014-05-06T00:00:00","2014-05-07T00:00:00","2014-05-08T00:00:00","2014-05-09T00:00:00","2014-05-12T00:00:00","2014-05-13T00:00:00","2014-05-14T00:00:00","2014-05-15T00:00:00","2014-05-16T00:00:00","2014-05-19T00:00:00","2014-05-20T00:00:00","2014-05-21T00:00:00","2014-05-22T00:00:00","2014-05-23T00:00:00","2014-05-26T00:00:00","2014-05-27T00:00:00","2014-05-28T00:00:00","2014-05-29T00:00:00","2014-05-30T00:00:00","2014-06-02T00:00:00","2014-06-03T00:00:00","2014-06-04T00:00:00","2014-06-05T00:00:00","2014-06-06T00:00:00","2014-06-09T00:00:00","2014-06-10T00:00:00","2014-06-11T00:00:00","2014-06-12T00:00:00","2014-06-13T00:00:00","2014-06-16T00:00:00","2014-06-17T00:00:00","2014-06-18T00:00:00","2014-06-19T00:00:00","2014-06-20T00:00:00","2014-06-23T00:00:00","2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-06-30T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-04T00:00:00","2014-07-07T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-14T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-21T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-28T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-04T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-11T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-18T00:00:00","2014-08-19 ...

# %% [markdown]
# After Sept 2020, The stock price is steadily increasing but there's steep downfall in stock volume.

# %%
# Calculating grwth % if stock price and index point
stock_growth = round(((df.stock_price[2207] - df.stock_price[0])/df.stock_price[0])*100)
index_growth = round(((df.index_point[2207] - df.index_point[0])/df.index_point[0])*100)

print("Reliance Stock Price Growth:", stock_growth, "%")
print(f"Nifty 50 Index Growth:", index_growth, "%")
# Out:
# Reliance Stock Price Growth: 488 %
# Nifty 50 Index Growth: 191 %

# %%
# Creating bar plot
asset = ['Reliance Stock Price', 'Nifty 50 Index Point']
growth = [stock_growth, index_growth]
fig = px.bar(x=asset, y=growth, title='Bar Plot Example')

fig.update_traces(text=growth, textposition='inside')
fig.update_layout(yaxis_title='Growth %', xaxis_title='')
fig.update_layout(plot_bgcolor='#e6ffe6')
fig.update_yaxes(showgrid=True, gridcolor='white', gridwidth=5)
colors = ['blue', 'orange']
fig.update_traces(marker_color=colors)

fig.show()
# Out:
# <div>                            <div id="32ff23f3-7c92-4ef8-8db2-50bf9aa093c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32ff23f3-7c92-4ef8-8db2-50bf9aa093c3")) {                    Plotly.newPlot(                        "32ff23f3-7c92-4ef8-8db2-50bf9aa093c3",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":["blue","orange"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"inside","x":["Reliance Stock Price","Nifty 50 Index Point"],"xaxis":"x","y":[488,191],"yaxis":"y","type":"bar","text":["488","191"]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpol ...

# %% [markdown]
# The growth percentage of reliance stock is considerably high as compared to nifty 50 index.

# %% [markdown]
# # Alpha Beta Analysis

# %%
# Calculating daily returns
df['stock_return'] = df['stock_price'].pct_change()
df['index_return'] = df['index_point'].pct_change()

# Calculating covariance between stock returns and market returns
covariance = np.cov(df['Stock Returns'].dropna(), df['Market Returns'].dropna())[0][1]

# Calculate variance of market returns
variance_market = np.var(df['Market Returns'].dropna())

# Calculate beta
beta = round(covariance / variance_market, 2)

print("Volatility Indicator (Beta)", beta)
print("Reliance stock in question tends to be slightly more volatile than the overall market.")
# Out:
# Volatility Indicator (Beta) 1.09
# Reliance stock in question tends to be slightly more volatile than the overall market.

# %%
# Calculating alpha
risk_free_rate = 7.16 
market_return = df['index_return'].mean() 
beta = 1.09  

df['Alpha'] = df['stock_return'] - (risk_free_rate + beta * (market_return - risk_free_rate))

alpha = round(df['Alpha'].mean(), 2)

print("Return Indicator (Alpha):", alpha)
print("Reliance stock has performed better than what would be expected based on the overall market trends.")
# Out:
# Return Indicator (Alpha): 0.64
# Reliance stock has performed better than what would be expected based on the overall market trends.

# %% [markdown]
# # Summary

# %% [markdown]
# 1. **Descriptive Statistics:**
#    - Mean of Reliance Stock Price: ₹1,221
#    - Median of Reliance Stock Price: ₹977
#    - Standard Deviation of Reliance Stock Price: ₹759
#    - Mean of Nifty 50 Index Point: 11,115
#    - Median of Nifty 50 Index Point: 10454
#    - Standard Deviation of Nifty 50 Index Point: 3373
#
#    <br>
#
# 2. **Stock Price Distribution:**
#    - The median of the stock price is near the first quartile (Q1), suggesting more instances of lower stock prices compared to higher ones.
#
#    <br>
#
# 3. **Index Point Distribution:**
#    - The median of the index point is near the first quartile (Q1), indicating more instances of lower index points compared to higher ones.
#
#    <br>
#
# 4. **Correlation Analysis:**
#    - There's a strong positive correlation (0.94) between the stock price and the index point.
#    - Additionally, a weak positive correlation (0.5) exists between stock volume and index volume.
#    - Most of the time, the stock price and index point follow the same trend, although there are a few exceptions.
#
#    <br>
#
# 5. **Trend Observation:**
#    - Post-September 2020, the stock price has been steadily increasing, but there's a notable steep downfall in stock volume.
#
#    <br>
#
# 6. **Growth Analysis:**
#    - Reliance Stock Price Growth: 488%
#    - Nifty 50 Index Growth: 191%
#    - The growth percentage of Reliance stock is considerably higher than that of the Nifty 50 index.
#
#    <br>
#
# 7. **Volatility Indicator (Beta):**
#    - Volatility Indicator (Beta): 1.09
#    - The Reliance stock tends to be slightly more volatile than the overall market.
#
#    <br>
#
# 8. **Return Indicator (Alpha):**
#    - Return Indicator (Alpha): 0.64
#    - Reliance stock has performed better than expected based on the overall market trends.
